# %%
import aris.utils.warp_test_utils as warp_test

# %%
warp_test.visualize_warping_ui()
# Out:
# ...
# FigureWidget({
#     'data': [{'marker': {'size': 2},
#               'mode': 'markers',
#               'type': 'scatter3d',
#               'uid': '3bdf1383-497a-497f-bc01-cf5fbf24a8f7',
#               'x': [0],
#               'y': [0],
#               'z': [0]}],
#     'layout': {'margin': {'b': 0, 'l': 0, 'r': 0, 't': 0},
#                'scene': {'aspectmode': 'cube',
#                          'xaxis': {'range': [-1, 1]},
#                          'yaxis': {'range': [-1, 1]},
#                          'zaxis': {'range': [-1, 1]}},
#                'template': '...'}
# })

# %%
warp_test.check_warping()
# Out:
# Check uniform_square...     Passed, avg pdf error is 0.0000e+00 (pass), max is 0.0000e+00 (pass)
# Check tent...               Passed, avg pdf error is 1.9159e-08 (pass), max is 1.1921e-07 (pass)
# Check uniform_disk...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 warp_test.check_warping()
#
# File ~/Projects/School/CMSC740/aris-renderer/aris/utils/warp_test_utils.py:224, in check_warping()
#     222 try:
#     223     print(f"Check {name+'...':<{length+4}}", end="")
# --> 224     warp.check(1000)
#     225 except ValueError as err:
#     226     print(str(err))
#
# File ~/Projects/School/CMSC740/aris-renderer/aris/utils/warp_test_utils.py:31, in WarpDef.check(self, n_points)
#      29 def check(self, n_points):
#      30     uv = torch.rand(n_points, 2, requires_grad=True)
# ---> 31     points = self.warp_func(uv)
# ...
