# %%
import aris.utils.warp_test_utils as warp_test

# %%
warp_test.visualize_warping_ui()
# Out:
# ...
# FigureWidget({
#     'data': [{'marker': {'size': 2},
#               'mode': 'markers',
#               'type': 'scatter3d',
#               'uid': '3c515230-a3e4-4f6c-acbb-b710b2ddeaf1',
#               'x': [0],
#               'y': [0],
#               'z': [0]}],
#     'layout': {'margin': {'b': 0, 'l': 0, 'r': 0, 't': 0},
#                'scene': {'aspectmode': 'cube',
#                          'xaxis': {'range': [-1, 1]},
#                          'yaxis': {'range': [-1, 1]},
#                          'zaxis': {'range': [-1, 1]}},
#                'template': '...'}
# })

# %%
warp_test.check_warping()
# Out:
# Check uniform_square...     Passed, avg pdf error is 0.0000e+00 (pass), max is 0.0000e+00 (pass)
# Check tent...               Passed, avg pdf error is 2.0287e-08 (pass), max is 1.1921e-07 (pass)
# Check uniform_disk...       Passed, avg pdf error is 2.4706e-08 (pass), max is 1.1921e-07 (pass)
# Check uniform_sphere...     Passed, avg pdf error is 1.0245e-08 (pass), max is 3.3528e-07 (pass)
# Check uniform_hemisphere... Passed, avg pdf error is 2.6822e-08 (pass), max is 4.6641e-06 (pass)
# Check cosine_hemisphere...  Passed, avg pdf error is 3.6711e-08 (pass), max is 1.1086e-05 (pass)
# Check beckmann_0.1...       Passed, avg pdf error is 1.4266e-04 (pass), max is 1.4687e-03 (pass)
# Check beckmann_0.5...       Passed, avg pdf error is 3.3418e-07 (pass), max is 3.0756e-05 (pass)
# Check beckmann_0.9...       Passed, avg pdf error is 7.8924e-08 (pass), max is 1.3798e-05 (pass)
